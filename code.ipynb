# %%
from textblob import TextBlob

# %%
s = 'I hate being in traffic'
s2 = 'I love to eat pizza'

# %%
blob = TextBlob(s2)
blob2 = TextBlob(s)

# %%
print(

    blob.sentiment.polarity,
    blob2.sentiment.polarity
    
)
# Out:
# 0.5 -0.8
